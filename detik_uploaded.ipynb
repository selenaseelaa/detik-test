# %% [markdown]
# <a href="https://colab.research.google.com/github/selenaseelaa/detik-test/blob/main/detik_uploaded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library and other Dependencies**

# %%
import pandas as pd
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sklearn
import seaborn as sns
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Load Cleaned df**

# %%
url = 'https://raw.githubusercontent.com/selenaseelaa/detik-test/main/df.xlsx'

df = pd.read_excel(url)
df.columns = df.columns.str.lower()
df.info()
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           1000 non-null   object
#  1   product code      1000 non-null   object
#  2   total purchase    1000 non-null   int64
#  3   delivery service  1000 non-null   object
#  4   new customer      1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB
#           country product code  total purchase delivery service new customer
# ...

# %%
from sklearn.preprocessing import LabelEncoder

df_encoded = df.copy()
label_encoders = {}
for column in df_encoded.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df_encoded[column] = label_encoders[column].fit_transform(df_encoded[column])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_encoded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      country  product code  total purchase  delivery service  new customer
# 0          9             4               5                 0             1
# 1          2             9               3                 0             0
# 2          8             8               7                 1             1
# 3          0             7               9                 2             1
# 4          4             9               7                 1             0
# ..       ...           ...             ...               ...           ...
# 995        1             3               7                 2             1
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

basket = df_encoded.applymap(lambda x: 1 if x > 0 else 0)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket, min_support=0.1, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Clean the rules DataFrame
rules_df = rules[['antecedents', 'consequents', 'antecedent support',
                  'consequent support', 'support', 'confidence',
                  'lift', 'leverage', 'conviction', 'zhangs_metric']].copy()

# Convert frozen sets to strings for better readability
rules_df['antecedents'] = rules_df['antecedents'].apply(lambda x: ', '.join(list(x)))
rules_df['consequents'] = rules_df['consequents'].apply(lambda x: ', '.join(list(x)))

# Display the cleaned DataFrame
print(rules_df.head(20))
rules.to_csv('rules.csv', index=False)
# Out:
#          antecedents       consequents  antecedent support  \
# 0            country      product code               0.918
# 1       product code           country               0.944
# 2            country    total purchase               0.918
# 3     total purchase           country               1.000
# 4            country  delivery service               0.918
# 5   delivery service           country               0.802
# 6            country      new customer               0.918
# 7       new customer           country               0.753
# 8       product code    total purchase               0.944
# 9     total purchase      product code               1.000
# 10      product code  delivery service               0.944
# 11  delivery service      product code               0.802
# 12      product code      new customer               0.944
# 13      new customer      product code               0.753
# 14    total purchase  delivery service               1.000
# ...

# %%
# Display the top rules by confidence
top_rules = rules.sort_values(by=['confidence', 'lift'], ascending=False).head(10)
top_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                          antecedents       consequents  antecedent support  \
# 2                          (country)  (total purchase)               0.918
# 8                     (product code)  (total purchase)               0.944
# 15                (delivery service)  (total purchase)               0.802
# 16                    (new customer)  (total purchase)               0.753
# 20           (country, product code)  (total purchase)               0.865
# ...
